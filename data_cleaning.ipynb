# %%
import pandas as pd
import numpy as np

# %%
# Replace with your Google Sheet URL and modify the link as required
google_sheet_url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vR3JkRcj5YY4SN7kJzwNyPokTBK_QP_HgV59zsxX6nGEODRVcB6QaX2bJ02ifTm4Q/pub?output=csv'
csv_url = google_sheet_url.replace('/edit?usp=sharing', '/gviz/tq?tqx=out:csv')

main_df = pd.read_csv(csv_url)

main_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                              InvoiceDate  UnitPrice  CustomerID  \
# ...

# %%
main_df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
# Renaming columns

main_df.columns = ["invoice_id", "stock_id", "product_name", "purchase_quantity","invoice_full_time", "item_price", "customer_id","customer_country"]

c
# Out:
#   invoice_id stock_id                         product_name  purchase_quantity  \
# 0     536365   85123A   WHITE HANGING HEART T-LIGHT HOLDER                  6
# 1     536365    71053                  WHITE METAL LANTERN                  6
# 2     536365   84406B       CREAM CUPID HEARTS COAT HANGER                  8
# 3     536365   84029G  KNITTED UNION FLAG HOT WATER BOTTLE                  6
# 4     536365   84029E       RED WOOLLY HOTTIE WHITE HEART.                  6
#
#                   invoice_full_time  item_price  customer_id customer_country
# 0  Wednesday 1 December 2010, 08:26        2.55      17850.0   United Kingdom
# 1  Wednesday 1 December 2010, 08:26        3.39      17850.0   United Kingdom
# 2  Wednesday 1 December 2010, 08:26        2.75      17850.0   United Kingdom
# 3  Wednesday 1 December 2010, 08:26        3.39      17850.0   United Kingdom
# 4  Wednesday 1 December 2010, 08:26        3.39      17850.0   United Kingdom

# %%
main_df.head(60)
# Out:
#    invoice_id stock_id                         product_name  \
# 0      536365   85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1      536365    71053                  WHITE METAL LANTERN
# 2      536365   84406B       CREAM CUPID HEARTS COAT HANGER
# 3      536365   84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4      536365   84029E       RED WOOLLY HOTTIE WHITE HEART.
# 5      536365    22752         SET 7 BABUSHKA NESTING BOXES
# 6      536365    21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 7      536366    22633               HAND WARMER UNION JACK
# 8      536366    22632            HAND WARMER RED POLKA DOT
# 9      536367    84879        ASSORTED COLOUR BIRD ORNAMENT
# 10     536367    22745           POPPY'S PLAYHOUSE BEDROOM
# 11     536367    22748            POPPY'S PLAYHOUSE KITCHEN
# 12     536367    22749    FELTCRAFT PRINCESS CHARLOTTE DOLL
# 13     536367    22310              IVORY KNITTED MUG COSY
# 14     536367    84969   BOX OF 6 ASSORTED COLOUR TEASPOONS
# ...

# %%
main_df.tail(5)
# Out:
#        invoice_id stock_id                     product_name  \
# 541904     581587    22613      PACK OF 20 SPACEBOY NAPKINS
# 541905     581587    22899     CHILDREN'S APRON DOLLY GIRL
# 541906     581587    23254    CHILDRENS CUTLERY DOLLY GIRL
# 541907     581587    23255  CHILDRENS CUTLERY CIRCUS PARADE
# 541908     581587    22138    BAKING SET 9 PIECE RETROSPOT
#
#         purchase_quantity              invoice_full_time  item_price  \
# 541904                 12  Friday 9 December 2011, 12:50        0.85
# 541905                  6  Friday 9 December 2011, 12:50        2.10
# 541906                  4  Friday 9 December 2011, 12:50        4.15
# 541907                  4  Friday 9 December 2011, 12:50        4.15
# 541908                  3  Friday 9 December 2011, 12:50        4.95
#
#         customer_id customer_country
# 541904      12680.0           France
# 541905      12680.0           France
# 541906      12680.0           France
# 541907      12680.0           France
# ...

# %%
## Rami suggested creating categories
## Look into ARIMA and Prophet models

main_df["product_name"].nunique()
# Out:
# 4223

# %%
main_df["customer_country"].value_counts()
# Out:
# customer_country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# ...

# %%
### Taking care of special cases in customer_country column

# %%
# Custom taking care of special cases
def convert_countries(row):
    if row == "Unspecified" or row == "European Community":
        return np.nan
    elif row == "EIRE":
        return "Ireland"
    elif row == "RSA":
        return "South Africa"
    else:
        return row

# Apply custom function to each element in DataFrame column 'A'
main_df['customer_country'] = main_df['customer_country'].apply(convert_countries)

# %%
main_df["customer_country"].value_counts()
# Out:
# customer_country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# Ireland                   8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
main_df.shape
# Out:
# (541909, 8)

# %%
### Creating customer_region
# UK
# Europe
# Americas
# Asia
# Africa

# UK
uk = ["United Kingdom", "Channel Islands"]

# Europe
europe = [
    "Germany", "France", "Ireland", "Spain", "Netherlands", "Belgium",
    "Switzerland", "Portugal", "Norway", "Italy", "Finland", "Cyprus",
    "Sweden", "Austria", "Denmark", "Poland", "Iceland", "Greece",
    "Malta", "Lithuania", "Czech Republic"]

# Americas
americas = ["USA", "Canada", "Brazil"]

# Asia
asia = [
    "Japan", "Israel", "Hong Kong", "Singapore", "United Arab Emirates",
    "Lebanon", "Bahrain", "Saudi Arabia"
]

# Africa
africa = ["South Africa"]

# %%
## Handle NA values
